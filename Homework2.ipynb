# %% [markdown]
# <a href="https://colab.research.google.com/github/kamransadigli/DataScience/blob/main/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1-Read the data https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv
df=pd.read_csv("https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv")
df
# Out:
#       Income  Limit  Rating  Cards  Age  ...  Own Student Married Region Balance
# 0     14.891   3606     283      2   34  ...   No      No     Yes  South     333
# 1    106.025   6645     483      3   82  ...  Yes     Yes     Yes   West     903
# 2    104.593   7075     514      4   71  ...   No      No      No   West     580
# 3    148.924   9504     681      3   36  ...  Yes      No      No   West     964
# 4     55.882   4897     357      2   68  ...   No      No     Yes  South     331
# ..       ...    ...     ...    ...  ...  ...  ...     ...     ...    ...     ...
# 395   12.096   4100     307      3   32  ...   No      No     Yes  South     560
# 396   13.364   3838     296      5   65  ...   No      No      No   East     480
# 397   57.872   4171     321      5   67  ...  Yes      No     Yes  South     138
# 398   37.728   2525     192      1   44  ...   No      No     Yes  South       0
# 399   18.701   5524     415      5   64  ...  Yes      No      No   West     966
#
# [400 rows x 11 columns]

# %%
#Q2- Get data information and number of rows and columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Income     400 non-null    float64
#  1   Limit      400 non-null    int64
#  2   Rating     400 non-null    int64
#  3   Cards      400 non-null    int64
#  4   Age        400 non-null    int64
#  5   Education  400 non-null    int64
#  6   Own        400 non-null    object
#  7   Student    400 non-null    object
#  8   Married    400 non-null    object
#  9   Region     400 non-null    object
#  10  Balance    400 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 34.5+ KB

# %%
#Q3-Get first 3 rows of data
df[0:3]
# Out:
#     Income  Limit  Rating  Cards  Age  ...  Own Student Married Region Balance
# 0   14.891   3606     283      2   34  ...   No      No     Yes  South     333
# 1  106.025   6645     483      3   82  ...  Yes     Yes     Yes   West     903
# 2  104.593   7075     514      4   71  ...   No      No      No   West     580
#
# [3 rows x 11 columns]

# %%
#Q4-Get descriptive statistics of data
df.describe()
# Out:
#            Income         Limit  ...   Education      Balance
# count  400.000000    400.000000  ...  400.000000   400.000000
# mean    45.218885   4735.600000  ...   13.450000   520.015000
# std     35.244273   2308.198848  ...    3.125207   459.758877
# min     10.354000    855.000000  ...    5.000000     0.000000
# 25%     21.007250   3088.000000  ...   11.000000    68.750000
# 50%     33.115500   4622.500000  ...   14.000000   459.500000
# 75%     57.470750   5872.750000  ...   16.000000   863.000000
# max    186.634000  13913.000000  ...   20.000000  1999.000000
#
# [8 rows x 7 columns]

# %%
#Q5-Use seasoborns heat map to generate following heatmap
# annot = True to print the correlation inside the square
sns.heatmap(df.corr(),annot=True)

# %%
#Q6-Plot the density distribution of Balance
sns.displot(df['Balance'],kind='kde')

# %%
#Q7-Count the frequency values of each Region
df.Region.value_counts()
# Out:
# South    199
# West     102
# East      99
# Name: Region, dtype: int64

# %%
#Q8-List Percentage of  the Married people
df.Married.value_counts(normalize=True)
# Out:
# Yes    0.6125
# No     0.3875
# Name: Married, dtype: float64

# %%
#Q9-Create histogram of Balance
plt.hist(df["Balance"])
# Out:
# (array([138.,  45.,  53.,  47.,  48.,  32.,  21.,  11.,   3.,   2.]),
#  array([   0. ,  199.9,  399.8,  599.7,  799.6,  999.5, 1199.4, 1399.3,
#         1599.2, 1799.1, 1999. ]),
#  <a list of 10 Patch objects>)

# %%
#Q10-Get the frequency distribution of Region using bar graph
df.Region.value_counts(normalize=True).plot(kind="bar")

# %%
#Q11-Get the mean income  of married people?
d = {"No": False, "Yes": True}
df["Married"] = df["Married"].map(d)
df.head()
# Out:
#     Income  Limit  Rating  Cards  Age  ...  Own Student Married  Region Balance
# 0   14.891   3606     283      2   34  ...   No      No    True   South     333
# 1  106.025   6645     483      3   82  ...  Yes     Yes    True    West     903
# 2  104.593   7075     514      4   71  ...   No      No   False    West     580
# 3  148.924   9504     681      3   36  ...  Yes      No   False    West     964
# 4   55.882   4897     357      2   68  ...   No      No    True   South     331
#
# [5 rows x 11 columns]

# %%
df[df["Married"] == 1]["Income"].mean()
# Out:
# 46.21708163265304

# %%
#Q12-Get the scatter plot of Income and Credit
sns.lmplot(x='Income',y='Limit',data=df)

# %%
#Q13-Create new column named IncomebyLimit by dividing Income to Limit. 
df['IncomebyLimit'] = df['Income'] / df['Limit']
df
# Out:
#       Income  Limit  Rating  Cards  ...  Married  Region Balance IncomebyLimit
# 0     14.891   3606     283      2  ...     True   South     333      0.004130
# 1    106.025   6645     483      3  ...     True    West     903      0.015956
# 2    104.593   7075     514      4  ...    False    West     580      0.014783
# 3    148.924   9504     681      3  ...    False    West     964      0.015670
# 4     55.882   4897     357      2  ...     True   South     331      0.011411
# ..       ...    ...     ...    ...  ...      ...     ...     ...           ...
# 395   12.096   4100     307      3  ...     True   South     560      0.002950
# 396   13.364   3838     296      5  ...    False    East     480      0.003482
# 397   57.872   4171     321      5  ...     True   South     138      0.013875
# 398   37.728   2525     192      1  ...     True   South       0      0.014942
# 399   18.701   5524     415      5  ...    False    West     966      0.003385
#
# [400 rows x 12 columns]

# %%
# Q14-Create the pair plot using Seaborn library's pairplot
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-22d7b5cb5e94> in <module>()
#       1 # Q14-Create the pair plot using Seaborn library's pairplot
# ----> 2 sns.pairplot(df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124     diag_kws.setdefault("legend", False)
#    2125     if diag_kind == "hist":
# -> 2126         grid.map_diag(histplot, **diag_kws)
#    2127     elif diag_kind == "kde":
#    2128         diag_kws.setdefault("fill", True)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1473             estimate_kws=estimate_kws,
#    1474             line_kws=line_kws,
# -> 1475             **kwargs,
#    1476         )
#    1477
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     439
#     440             # Do the histogram computation
# --> 441             heights, edges = estimator(observations, weights=weights)
#     442
#     443             # Rescale the smoothed curve to match the histogram
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     384         """Count the occurrences in each bin, maybe normalize."""
#     385         if x2 is None:
# --> 386             return self._eval_univariate(x1, weights)
#     387         else:
#     388             return self._eval_bivariate(x1, x2, weights)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     359         bin_kws = self.bin_kws
#     360         if bin_kws is None:
# --> 361             bin_kws = self.define_bin_params(x, weights=weights, cache=False)
#     362
#     363         density = self.stat == "density"
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in define_bin_params(self, x1, x2, weights, cache)
#     268
#     269             bin_edges = self._define_bin_edges(
# --> 270                 x1, weights, self.bins, self.binwidth, self.binrange, self.discrete,
#     271             )
#     272
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _define_bin_edges(self, x, weights, bins, binwidth, binrange, discrete)
#     259         else:
#     260             bin_edges = np.histogram_bin_edges(
# --> 261                 x, bins, binrange, weights,
#     262             )
#     263         return bin_edges
#
# <__array_function__ internals> in histogram_bin_edges(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram_bin_edges(a, bins, range, weights)
#     667     """
#     668     a, weights = _ravel_and_check_weights(a, weights)
# --> 669     bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     670     return bin_edges
#     671
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     407         else:
#     408             # Do not call selectors on empty arrays
# --> 409             width = _hist_bin_selectors[bin_name](a, (first_edge, last_edge))
#     410             if width:
#     411                 n_equal_bins = int(np.ceil(_unsigned_subtract(last_edge, first_edge) / width))
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _hist_bin_auto(x, range)
#     262     """
#     263     fd_bw = _hist_bin_fd(x, range)
# --> 264     sturges_bw = _hist_bin_sturges(x, range)
#     265     del range  # unused
#     266     if fd_bw:
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _hist_bin_sturges(***failed resolving arguments***)
#      71     """
#      72     del range  # unused
# ---> 73     return _ptp(x) / (np.log2(x.size) + 1.0)
#      74
#      75
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _ptp(x)
#      27     This function returns an unsigned value for signed integer arrays.
#      28     """
# ---> 29     return _unsigned_subtract(x.max(), x.min())
#      30
#      31
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
# --> 353         return np.subtract(a, b, dtype=dt)
#     354     else:
#     355         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
#Q15- drop new column named IncomebyLimit from dataframe
df.drop('IncomebyLimit',axis=1)
# Out:
#       Income  Limit  Rating  Cards  Age  ...  Own Student Married  Region Balance
# 0     14.891   3606     283      2   34  ...   No      No    True   South     333
# 1    106.025   6645     483      3   82  ...  Yes     Yes    True    West     903
# 2    104.593   7075     514      4   71  ...   No      No   False    West     580
# 3    148.924   9504     681      3   36  ...  Yes      No   False    West     964
# 4     55.882   4897     357      2   68  ...   No      No    True   South     331
# ..       ...    ...     ...    ...  ...  ...  ...     ...     ...     ...     ...
# 395   12.096   4100     307      3   32  ...   No      No    True   South     560
# 396   13.364   3838     296      5   65  ...   No      No   False    East     480
# 397   57.872   4171     321      5   67  ...  Yes      No    True   South     138
# 398   37.728   2525     192      1   44  ...   No      No    True   South       0
# 399   18.701   5524     415      5   64  ...  Yes      No   False    West     966
#
# [400 rows x 11 columns]
